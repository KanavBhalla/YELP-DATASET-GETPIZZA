# %%
import pandas as pd

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
yelp= pd.read_csv("pizza.csv")
yelp
# Out:
#                  business_id                               name  neighborhood  \
# 0     sxQrSzv4SS4b6o3tgmWS7A                 "Chuck E Cheese's"           NaN
# 1     Ql0iiHl2xpIwtkuC255Wiw  "John's Incredible Pizza Company"      Eastside
# 2     pbUsYtULpwmhZXlzeTfcww                   "Stone & Barrel"           NaN
# 3     gWsWtppVufrGfGWw1HcjOA                      "Dream Lanes"           NaN
# 4     T0ju0drMLfXJPNLnEsEYgw                  "Pizza Hot Wings"   Scarborough
# ...                      ...                                ...           ...
# 6062  7JkPRXmtRmspIX_k3zMNvg     "Teatro Pizzeria and Wine Bar"           NaN
# 6063  w2IE4nbufBqwrub7CW80xg                 "Goodfellas Pizza"  Streetsville
# 6064  ToFm2DhhTdr0Kv0A7Sdj6g                    "Timo Wine Bar"           NaN
# 6065  SHHnB7GsNyA3y5dg-P-LMw                  "Luca's Pizzeria"          Etna
# 6066  mSWNf1muSy9wgGtMRgt7Fg        "Zeppe's Tavern & Pizzeria"           NaN
#
#                        address             city state postal_code   latitude  \
# 0       "1035 Washington Pike"      Bridgeville    PA       15017  40.364665
# 1       "3700 S Maryland Pkwy"        Las Vegas    NV       89119  36.122106
# 2       "24218 S Oakwood Blvd"        Sun Lakes    AZ       85248  33.227038
# 3                "13 Atlas Ct"          Madison    WI       53714  43.086793
# 4     "3007 Sheppard Avenue E"          Toronto    ON     M1T 3J5  43.776407
# ...                        ...              ...   ...         ...        ...
# 6062   "32409 N Scottsdale Rd"       Scottsdale    AZ       85266  33.780331
# 6063      "209 Queen Street S"      Mississauga    ON     L5M 1X3  43.581159
# 6064      "8801 N Central Ave"          Phoenix    AZ       85020  33.564620
# 6065           "183 Butler St"       Pittsburgh    PA       15223  40.493356
# 6066          "25780 Miles Rd"  Bedford Heights    OH       44146  41.423691
#
#        longitude  stars  review_count  is_open  \
# 0     -80.110620    3.0            11        1
# 1    -115.134871    3.0           268        1
# 2    -111.873780    4.0            23        1
# 3     -89.306868    3.0             8        1
# 4     -79.318135    3.5             3        0
# ...          ...    ...           ...      ...
# 6062 -111.925748    3.5            45        0
# 6063  -79.712981    3.5           116        1
# 6064 -112.073585    4.0           337        1
# 6065  -79.948553    3.0            10        0
# 6066  -81.496985    3.5            13        1
#
#                                              categories
# 0     Active Life;Arts & Entertainment;Restaurants;V...
# 1     Active Life;Pizza;Arts & Entertainment;Kids Ac...
# 2     Active Life;Restaurants;Nightlife;American (Tr...
# 3     Active Life;Toy Stores;Shopping;Pizza;Event Pl...
# 4                        Afghan;Halal;Pizza;Restaurants
# ...                                                 ...
# 6062  Wine Bars;Restaurants;Italian;Pizza;Bars;Night...
# 6063  Wine Bars;Restaurants;Nightlife;Bars;Italian;F...
# 6064  Wine Bars;Tapas/Small Plates;Pizza;Restaurants...
# 6065   Wraps;Restaurants;Pizza;Sandwiches;Chicken Wings
# 6066  Wraps;Sandwiches;American (Traditional);Italia...
#
# [6067 rows x 13 columns]

# %%
yelp.describe()
# Out:
#           latitude    longitude        stars  review_count      is_open
# count  6067.000000  6067.000000  6067.000000   6067.000000  6067.000000
# mean     39.536523   -88.233598     3.348772     49.129553     0.792484
# std       5.007670    24.455903     0.829963    121.137196     0.405562
# min     -34.515952  -115.350952     1.000000      3.000000     0.000000
# 25%      35.200027  -111.939013     3.000000      6.000000     1.000000
# 50%      40.440941   -81.358555     3.500000     15.000000     1.000000
# 75%      43.648540   -79.554400     4.000000     44.000000     1.000000
# max      59.436505    14.092636     5.000000   3741.000000     1.000000

# %%
yelp.columns
# Out:
# Index(['business_id', 'name', 'neighborhood', 'address', 'city', 'state',
#        'postal_code', 'latitude', 'longitude', 'stars', 'review_count',
#        'is_open', 'categories'],
#       dtype='object')

# %%
yelp.dtypes
# Out:
# business_id      object
# name             object
# neighborhood     object
# address          object
# city             object
# state            object
# postal_code      object
# latitude        float64
# longitude       float64
# stars           float64
# review_count      int64
# is_open           int64
# categories       object
# dtype: object

# %%
yelp = yelp.replace({'\$':''}, regex = True)

# %%
plt.scatter(yelp['stars'], yelp['review_count'])
#plot of relation between review count and stars

# %%
yelp.sort_values(by='stars', ascending=False)
# Out:
#                  business_id                         name   neighborhood  \
# 3473  Perap0eAyCbUx4r4rQTSnA                "Pie Express"        Oakland
# 4649  ihWw0eSKMQfO5cXLFS5itQ            "Homestyle Pizza"            NaN
# 3063  ueHTq9P9jbb5Ar0_zo6YKw          "Restaurant Dorion"            NaN
# 3537  NuT1ejKruFnBFQWC6Xg82w              "Papa Murphy's"  Spring Valley
# 5976  epyhvtf5JH5sAJggINVglg  "J&B's Pizza, BBQ And Deli"            NaN
# ...                      ...                          ...            ...
# 5197  YHN7wVaOFp9wkl_w7NXLXw     "Kens Burgers and Pizza"      Southeast
# 2198  Lvr6DdVkFI8IMGfRvUcXQA       "Little Caesars Pizza"            NaN
# 1621  wB8SWcTrYWSSZQkRgJ-C-w               "Boston Pizza"            NaN
# 3605  FduOLezzT4jWWArKcJ3K0w                "Pizza Pizza"            NaN
# 1759  9a2mS1xE93r5v500Lhx3AA                "Pizza Pizza"            NaN
#
#                               address              city state postal_code  \
# 3473                "148 Oakland Ave"        Pittsburgh    PA       15213
# 4649            "3350 Millers Run Rd"             Cecil    PA       15321
# 3063               "297 Boul Harwood"  Vaudreuil-Dorion    QC     J7V 1Y6
# 3537   "7210 S. Durango Dr., Suite A"         Las Vegas    NV       89113
# 5976             "9950 E Broadway Rd"              Mesa    AZ       85208
# ...                               ...               ...   ...         ...
# 5197      "7141 S Eastern Ave, Ste D"         Las Vegas    NV       89119
# 2198      "4340 W McDowell Rd, Ste 6"           Phoenix    AZ       85035
# 1621              "315 Guelph Street"        Georgetown    ON     L7G 4B3
# 3605  "1837 Finch Avenue W, Unit T-3"           Toronto    ON     M3N 2H1
# 1759           "168 Holland Street W"          Bradford    ON     L3Z 1H7
#
#        latitude   longitude  stars  review_count  is_open  \
# 3473  40.441635  -79.957214    5.0             7        1
# 4649  40.322359  -80.198772    5.0             3        1
# 3063  45.381110  -74.016218    5.0             5        1
# 3537  36.057182 -115.278528    5.0            44        1
# 5976  33.408120 -111.615811    5.0             5        0
# ...         ...         ...    ...           ...      ...
# 5197  36.059631 -115.119423    1.0             4        0
# 2198  33.466332 -112.153483    1.0             3        1
# 1621  43.650985  -79.888124    1.0             3        1
# 3605  43.756259  -79.515427    1.0             3        1
# 1759  44.112113  -79.570814    1.0             3        1
#
#                                              categories
# 3473                            Pizza;Restaurants;Salad
# 4649                                  Restaurants;Pizza
# 3063                                  Pizza;Restaurants
# 3537                Pizza;Salad;Gluten-Free;Restaurants
# 5976  Shopping;Food;Barbeque;Beer;Wine & Spirits;Del...
# ...                                                 ...
# 5197                          Restaurants;Pizza;Burgers
# 2198                                  Pizza;Restaurants
# 1621       Nightlife;Restaurants;Sports Bars;Pizza;Bars
# 3605             Pizza;Sandwiches;Restaurants;Fast Food
# 1759            Pizza;Chicken Wings;Italian;Restaurants
#
# [6067 rows x 13 columns]

# %%
 yelp.loc[yelp['stars'] == 5]
# Out:
#                  business_id                          name neighborhood  \
# 231   q-YQIvBSNZxYJl1xuB0H_w     "CM2 Pizzeria & Bakeshop"          NaN
# 279   j65Mnw8aFJkYgkt_UR5BOw  "Matt's Sub Shack and Pizza"          NaN
# 284   F6eEu0qhYpS99e1ag3q0Bw      "Braw Burgers And Pizza"    Newington
# 344   893VryJbZcCm5V9xon_aLA             "Those Guys Pies"    Northwest
# 352   Lkq-3a2oZUPDSUWBRzUXWg                 "Senor Pizza"          NaN
# ...                      ...                           ...          ...
# 5897  VsRAIb4k5CjEF-3l_bac0g      "Akropolis Gyro & Pizza"          NaN
# 5956  flCZyw8UBZF41dKMn8k_GQ                  "Joey's PSG"          NaN
# 5976  epyhvtf5JH5sAJggINVglg   "J&B's Pizza, BBQ And Deli"          NaN
# 5980  3xXU6QBovnxeLSOkrRQI8A                      "Nicola"       Avalon
# 6045  2xmZgzxGAFRvMEcbmXvBng                "Issi's Place"          NaN
#
#                                 address          city state postal_code  \
# 231                  "11485 N 136th St"    Scottsdale    AZ       85259
# 279   "812 Little Deer Creek Valley Rd"    Russellton    PA       15076
# 284                  "54A Clerk Street"     Edinburgh   EDH     EH8 9JQ
# 344      "3369 Thom Blvd, rose grilled"     Las Vegas    NV       89130
# 352                "1635 E Baseline Rd"       Phoenix    AZ       85042
# ...                                 ...           ...   ...         ...
# 5897        "1690 W Sunset Rd, Ste 104"     Henderson    NV       89014
# 5956                   "1038 E Main St"          Mesa    AZ       85203
# 5976               "9950 E Broadway Rd"          Mesa    AZ       85208
# 5980               "649 California Ave"    Pittsburgh    PA       15202
# 6045                   "14431 Cedar Rd"  South Euclid    OH         NaN
#
#        latitude   longitude  stars  review_count  is_open  \
# 231   33.590790 -111.786675    5.0            41        1
# 279   40.613075  -79.835287    5.0             5        1
# 284   55.942029   -3.181807    5.0             3        1
# 344   36.220039 -115.212351    5.0             5        0
# 352   33.377170 -112.045633    5.0            26        1
# ...         ...         ...    ...           ...      ...
# 5897  36.064347 -115.059518    5.0           214        1
# 5956  33.415592 -111.808551    5.0            39        1
# 5976  33.408120 -111.615811    5.0             5        0
# 5980  40.501175  -80.067173    5.0             3        0
# 6045  41.501723  -81.520262    5.0             4        1
#
#                                              categories
# 231   Breakfast & Brunch;Wine Bars;Restaurants;Food;...
# 279                Burgers;Pizza;Sandwiches;Restaurants
# 284                           Burgers;Restaurants;Pizza
# 344   Cheesesteaks;Pizza;Sandwiches;American (New);R...
# 352            Chicken Wings;Barbeque;Pizza;Restaurants
# ...                                                 ...
# 5897           Sandwiches;Pizza;Restaurants;Salad;Greek
# 5956                  Sandwiches;Restaurants;Soup;Pizza
# 5976  Shopping;Food;Barbeque;Beer;Wine & Spirits;Del...
# 5980          Soup;Italian;Restaurants;Pizza;Sandwiches
# 6045            Vegetarian;Pizza;Sushi Bars;Restaurants
#
# [123 rows x 13 columns]

# %%
star = yelp.loc[yelp['stars'] == 5]

# %%
star.sort_values(by='review_count', ascending=False)
# Out:
#                  business_id                       name  \
# 5897  VsRAIb4k5CjEF-3l_bac0g   "Akropolis Gyro & Pizza"
# 3475  FvXZcRB8bocNMDvFUnoWhg           "In Forno Pizza"
# 1538  E_jLyf_YuGgMP_rw8tvNSA   "Niko's Pizza Las Vegas"
# 1648  Llm_iXzE0-8_XKwI2e4JdA              "Saffron JAK"
# 4129  QnTguWLRKRK_reQ__8k7yw            "Do Wood Fired"
# ...                      ...                        ...
# 4756  UPKbATxvpapWcirMeRzCUw          "Ramona Pizzeria"
# 2693  FdajgRoHB_PlLr74-vcA_w            "Pizzeria 1926"
# 689   MJW4XuO_seWA19-fbmBRTA  "Blaze Fast-Fire'd Pizza"
# 756   wcfMZkhEADT32i5TTPqWEg               "Humble Pie"
# 4720  oHI9n_ocZyzuQgXlr2GUAQ        "Pizza Papa Gerald"
#
#                        neighborhood                           address  \
# 5897                            NaN       "1690 W Sunset Rd, Ste 104"
# 3475                            NaN                "35840 Chester Rd"
# 1538                  Spring Valley  "4555 S Fort Apache Rd, Ste 112"
# 1648                            NaN   "814 E Union Hills Dr, Ste C-6"
# 4129                            NaN                      "213 5th St"
# ...                             ...                               ...
# 4756  Mercier-Hochelaga-Maisonneuve              "5760 Rue Hochelaga"
# 2693                       West End                  "102 Dalry Road"
# 689                             NaN  "16201 N Scottsdale Rd, Ste 105"
# 756                             NaN                                ""
# 4720                            NaN             "146 Montee Du Comte"
#
#              city state postal_code   latitude   longitude  stars  \
# 5897    Henderson    NV       89014  36.064347 -115.059518    5.0
# 3475         Avon    OH       44011  41.468214  -82.015634    5.0
# 1538    Las Vegas    NV       89147  36.106433 -115.298019    5.0
# 1648      Phoenix    AZ       85024  33.656123 -112.062959    5.0
# 4129        Irwin    PA       15642  40.331382  -79.710323    5.0
# ...           ...   ...         ...        ...         ...    ...
# 4756    Montr̩al    QC     H1N 1W5  45.570684  -73.537339    5.0
# 2693    Edinburgh   EDH    EH11 2DW  55.943808   -3.218932    5.0
# 689    Scottsdale    AZ       85254  33.633114 -111.925375    5.0
# 756     Avon Lake    OH       44012  41.505318  -82.028200    5.0
# 4720  Les Coteaux    QC     J7X 1A2  45.258415  -74.214540    5.0
#
#       review_count  is_open                                         categories
# 5897           214        1           Sandwiches;Pizza;Restaurants;Salad;Greek
# 3475           123        1              Pizza;Restaurants;Salad;Desserts;Food
# 1538           118        1  Mediterranean;Pizza;Italian;Food Delivery Serv...
# 1648           100        1  Persian/Iranian;Food Trucks;Bakeries;Food;Rest...
# 4129            57        1               Restaurants;Italian;Pizza;Sandwiches
# ...            ...      ...                                                ...
# 4756             3        1                                  Restaurants;Pizza
# 2693             3        1                                  Pizza;Restaurants
# 689              3        1                  Fast Food;Pizza;Restaurants;Salad
# 756              3        1  Food;Bakeries;Pizza;Sandwiches;Automotive;Dess...
# 4720             3        1                                  Restaurants;Pizza
#
# [123 rows x 13 columns]

# %%
plt.scatter(star['review_count'], star['stars'])

# %%
star.describe()
# Out:
#          latitude   longitude  stars  review_count     is_open
# count  123.000000  123.000000  123.0    123.000000  123.000000
# mean    41.109900  -79.339617    5.0     12.317073    0.861789
# std      5.690015   33.998048    0.0     26.298824    0.346533
# min     33.217579 -115.311710    5.0      3.000000    0.000000
# 25%     36.085390 -111.800188    5.0      3.000000    1.000000
# 50%     41.407011  -80.000987    5.0      5.000000    1.000000
# 75%     44.423824  -78.051311    5.0      8.500000    1.000000
# max     55.970998    9.301130    5.0    214.000000    1.000000

# %%
yelp.sort_values(by='review_count', ascending=False)
# Out:
#                  business_id                  name neighborhood  \
# 2326  iCQpiavjjPzJ5_3gPD5Ebg        "Secret Pizza"    The Strip
# 3704  3kdSl5mo9dWC4clrQjEDGg             "Egg & I"     Westside
# 5613  pSQFynH1VxkfSmehRXlZWw     "Pizzeria Bianco"          NaN
# 48    JzOp695tclcNCNMuBl7oxA  "Four Peaks Brewing"          NaN
# 2633  3GEEy7RP6e4bT4LAiWFMFQ          "Pizza Rock"     Downtown
# ...                      ...                   ...          ...
# 4480  VOvcCzgnhyJ63r3Xk5gvpQ       "Vocelli Pizza"          NaN
# 4473  Uq2mlRObAytzkTIoerN03Q          "Pisa Pizza"          NaN
# 4464  7Ny6x4wX1JJLqdVeKQ1JYg            "Mama C's"          NaN
# 1077  1zB9uReur5fdEw5slte0gA           "Pizza Hut"          NaN
# 3500  SIGb2Q6PuoixOR4VtwgpgA      "Domino's Pizza"          NaN
#
#                                                 address         city state  \
# 2326  "The Cosmopolitan Of Las Vegas, 3708 Las Vegas...    Las Vegas    NV
# 3704                         "4533 W Sahara Ave, Ste 5"    Las Vegas    NV
# 5613                                   "623 E Adams St"      Phoenix    AZ
# 48                             "1340 E 8th St, Ste 104"        Tempe    AZ
# 2633                                     "201 N 3rd St"    Las Vegas    NV
# ...                                                 ...          ...   ...
# 4480                     "1025 Washington Pike, Ste 27"  Bridgeville    PA
# 4473                                  "2015 N Power Rd"         Mesa    AZ
# 4464                             "Ritzland Shopping Ct"   Pittsburgh    PA
# 1077                                "3490 Colorado Ave"       Lorain    OH
# 3500                                "147 Northwest Ave"    Tallmadge    OH
#
#      postal_code   latitude   longitude  stars  review_count  is_open  \
# 2326       89109  36.112372 -115.173064    4.0          3741        1
# 3704       89102  36.144046 -115.202465    4.5          2595        1
# 5613       85004  33.449160 -112.065635    4.0          2035        1
# 48         85281  33.419568 -111.916097    4.5          1965        1
# 2633       89101  36.171618 -115.142267    4.0          1738        1
# ...          ...        ...         ...    ...           ...      ...
# 4480       15017  40.367163  -80.110119    1.5             3        1
# 4473       85215  33.452097 -111.682916    3.0             3        0
# 4464       15235  40.458622  -79.818468    4.5             3        1
# 1077       44052  41.464661  -82.132709    3.5             3        1
# 3500       44278  41.105085  -81.446222    1.5             3        1
#
#                                              categories
# 2326                                  Pizza;Restaurants
# 3704  Restaurants;Burgers;American (Traditional);San...
# 5613         Restaurants;Salad;Pizza;Italian;Sandwiches
# 48    American (New);Sandwiches;Burgers;Nightlife;Ba...
# 2633                                  Pizza;Restaurants
# ...                                                 ...
# 4480                                  Restaurants;Pizza
# 4473                                  Restaurants;Pizza
# 4464                                  Restaurants;Pizza
# 1077            Italian;Pizza;Chicken Wings;Restaurants
# 3500         Pizza;Restaurants;Sandwiches;Chicken Wings
#
# [6067 rows x 13 columns]

# %%
yelp.loc[yelp['stars'] == 1]
# Out:
#                  business_id                            name neighborhood  \
# 416   OIpS3O5ifR0wFu5PdvMM5w                     "Pizza Hut"          NaN
# 451   O5vXNIody0SMddowzrAMXQ                     "Pizza Hut"          NaN
# 489   F2CdVtudYJlSgTAqWDX8gA                     "Pizza Hut"          NaN
# 506   CdqDmKlSVrTBigSZnpQYug                     "Pizza Hut"          NaN
# 509   XgsGLjUpVhfTqvkapVxYHw                     "Pizza Hut"          NaN
# ...                      ...                             ...          ...
# 5460  nzUv52JpOQz98Fk9GB4AKA                   "Pizza Pizza"          NaN
# 5478  n93mgR2PhSXmB_znHJBBGA                     "Pizza Hut"          NaN
# 5560  2koGK8csbE3AIFf7r2dMNw                "Domino's Pizza"          NaN
# 5686  57J9SvZCc1OS96ilcIJJGQ  "Murray and Sons Construction"          NaN
# 5910  S0yP4IZmwVpeqxSe0R2Fvw                        "Subway"    The Strip
#
#                                 address          city state postal_code  \
# 416                   "1165 Mentor Ave"   Painesville    OH       44077
# 451              "3734 W T Harris Blvd"     Charlotte    NC       28269
# 489                 "2324 Ardmore Blvd"  Forest Hills    PA       15221
# 506           "10050 W Bell Rd, Ste 22"      Sun City    AZ       85351
# 509                   "3044 Eastway Dr"     Charlotte    NC       28205
# ...                                 ...           ...   ...         ...
# 5460                "3358 Keele Street"    North York    ON     M3J 1L5
# 5478  "10 Jacob Keffer Parkway, Unit 1"       Concord    ON     L4K 5E3
# 5560                  "703 S Gammon Rd"       Madison    WI       53719
# 5686        "20783 N 83rd Ave, Ste 103"       Phoenix    AZ       85022
# 5910            "2890 Las Vegas Blvd S"     Las Vegas    NV       89109
#
#        latitude   longitude  stars  review_count  is_open  \
# 416   41.707083  -81.267351    1.0             5        1
# 451   35.333707  -80.795133    1.0            27        1
# 489   40.416164  -79.848449    1.0            16        1
# 506   33.639530 -112.276610    1.0             4        1
# 509   35.214200  -80.782256    1.0            10        1
# ...         ...         ...    ...           ...      ...
# 5460  43.745790  -79.487478    1.0             3        1
# 5478  43.836159  -79.506367    1.0             8        1
# 5560  43.049763  -89.502767    1.0             4        1
# 5686  33.641716 -112.067037    1.0             7        1
# 5910  36.135989 -115.163123    1.0            12        1
#
#                                              categories
# 416             Chicken Wings;Pizza;Italian;Restaurants
# 451             Chicken Wings;Pizza;Restaurants;Italian
# 489             Chicken Wings;Restaurants;Italian;Pizza
# 506             Chicken Wings;Restaurants;Pizza;Italian
# 509             Chicken Wings;Restaurants;Pizza;Italian
# ...                                                 ...
# 5460            Restaurants;Pizza;Italian;Chicken Wings
# 5478  Restaurants;Pizza;Italian;Fast Food;Chicken Wings
# 5560         Restaurants;Pizza;Sandwiches;Chicken Wings
# 5686  Restaurants;Tires;Business Consulting;Home Ins...
# 5910             Sandwiches;Restaurants;Fast Food;Pizza
#
# [69 rows x 13 columns]

# %%
lowstar = yelp.loc[yelp['stars'] == 1]
#list all of the restaurants with 1 star

# %%
plt.scatter(lowstar['review_count'], lowstar['stars'])

# %%
lowstar.describe()
# Out:
#         latitude   longitude  stars  review_count    is_open
# count  69.000000   69.000000   69.0     69.000000  69.000000
# mean   39.681012  -88.002616    1.0      5.753623   0.782609
# std     4.140976   19.182637    0.0      3.979380   0.415493
# min    33.414660 -115.282641    1.0      3.000000   0.000000
# 25%    35.333707 -111.940481    1.0      3.000000   1.000000
# 50%    40.586751  -80.946220    1.0      4.000000   1.000000
# 75%    43.655442  -79.696415    1.0      7.000000   1.000000
# max    48.690986    9.161919    1.0     27.000000   1.000000

# %%
lowstar.sort_values(by='review_count', ascending=False)
# Out:
#                  business_id                    name   neighborhood  \
# 451   O5vXNIody0SMddowzrAMXQ             "Pizza Hut"            NaN
# 489   F2CdVtudYJlSgTAqWDX8gA             "Pizza Hut"            NaN
# 3968  AyuE2AyyKSZj97SNLAHM9w                "Sbarro"  Downtown Core
# 5910  S0yP4IZmwVpeqxSe0R2Fvw                "Subway"      The Strip
# 5237  mILfcRQxAippB-Y6Bm4uiw             "Pizza Hut"            NaN
# ...                      ...                     ...            ...
# 3605  FduOLezzT4jWWArKcJ3K0w           "Pizza Pizza"            NaN
# 2198  Lvr6DdVkFI8IMGfRvUcXQA  "Little Caesars Pizza"            NaN
# 3262  MeCn3G6ZOl40FPCJ70kplg     "Fellinis Pizzeria"            NaN
# 2247  aVcbdppkdOG1ZORjek2n3A           "Pizza Pizza"    Ville-Marie
# 4267  H1LhTQWW_YCgJejzBSOFBw  "Little Caesars Pizza"            NaN
#
#                                        address          city state  \
# 451                     "3734 W T Harris Blvd"     Charlotte    NC
# 489                        "2324 Ardmore Blvd"  Forest Hills    PA
# 3968  "Toronto Eaton Center, 220 Yonge Street"       Toronto    ON
# 5910                   "2890 Las Vegas Blvd S"     Las Vegas    NV
# 5237            "3530 Mt Holly Hunterville Rd"     Charlotte    NC
# ...                                        ...           ...   ...
# 3605           "1837 Finch Avenue W, Unit T-3"       Toronto    ON
# 2198               "4340 W McDowell Rd, Ste 6"       Phoenix    AZ
# 3262                       "6028 Saltsburg Rd"        Verona    PA
# 2247               "1846 Rue Sainte-Catherine"     Montr̩al    QC
# 4267                         "613 Highland St"   Mount Holly    NC
#
#      postal_code   latitude   longitude  stars  review_count  is_open  \
# 451        28269  35.333707  -80.795133    1.0            27        1
# 489        15221  40.416164  -79.848449    1.0            16        1
# 3968     M5B 2H1  43.655442  -79.381671    1.0            15        1
# 5910       89109  36.135989 -115.163123    1.0            12        1
# 5237       28216  35.323266  -80.946220    1.0            12        1
# ...          ...        ...         ...    ...           ...      ...
# 3605     M3N 2H1  43.756259  -79.515427    1.0             3        1
# 2198       85035  33.466332 -112.153483    1.0             3        1
# 3262       15147  40.483948  -79.820262    1.0             3        1
# 2247     H3H 1M1  45.492950  -73.579880    1.0             3        1
# 4267       28120  35.287801  -81.017618    1.0             3        1
#
#                                           categories
# 451          Chicken Wings;Pizza;Restaurants;Italian
# 489          Chicken Wings;Restaurants;Italian;Pizza
# 3968  Restaurants;Italian;Fast Food;Food Court;Pizza
# 5910          Sandwiches;Restaurants;Fast Food;Pizza
# 5237         Restaurants;Pizza;Chicken Wings;Italian
# ...                                              ...
# 3605          Pizza;Sandwiches;Restaurants;Fast Food
# 2198                               Pizza;Restaurants
# 3262                          Pizza;Restaurants;Food
# 2247                               Pizza;Restaurants
# 4267                               Restaurants;Pizza
#
# [69 rows x 13 columns]

# %%
pizzahut= yelp.loc[yelp['name'] == '"Pizza Hut"']

# %%
yelp.loc[yelp['name'] == '"Pizza Hut"']
# Out:
#                  business_id         name      neighborhood  \
# 362   Gq4J8WD_mSY-o50R1PEKjw  "Pizza Hut"               NaN
# 365   NxZt-j74NpvIU5hdb2KJTA  "Pizza Hut"               NaN
# 373   7HjVdfoTqs4YbKqmoyKOeQ  "Pizza Hut"       Stockbridge
# 374   WFM2FE0THduTbnjgGdGDLQ  "Pizza Hut"               NaN
# 375   AZw_8ngMd8vnAbzKX7zPlw  "Pizza Hut"               NaN
# ...                      ...          ...               ...
# 5471  2KIlQsIHwYMkuwA0T4OKrw  "Pizza Hut"               NaN
# 5473  HRIUU2Z4EsZBo59P0I2ZYA  "Pizza Hut"               NaN
# 5474  cxrmfEWXlkgjB7zocBNkqA  "Pizza Hut"               NaN
# 5478  n93mgR2PhSXmB_znHJBBGA  "Pizza Hut"               NaN
# 6024  pwXkM4yHrcojgnx2qJQt7A  "Pizza Hut"  Brockton Village
#
#                                     address         city state postal_code  \
# 362   "Fife Leisure Scheme, Whimbrel Place"  Dunfermline   FIF    KY11 8EX
# 365          "2727 E McKellips Rd, Ste 106"         Mesa    AZ       85213
# 373                     "110 Raeburn Place"    Edinburgh   EDH     EH4 1HH
# 374               "80 Allegheny River Blvd"       Verona    PA       15147
# 375                   "1317 Savoy Plaza Ln"        Savoy    IL       61874
# ...                                     ...          ...   ...         ...
# 5471       "8225 W Indian School Rd, Ste 1"      Phoenix    AZ       85033
# 5473                   "377 Lear Rd, Ste A"    Avon Lake    OH       44012
# 5474                  "6771 University Ave"    Middleton    WI       53562
# 5478      "10 Jacob Keffer Parkway, Unit 1"      Concord    ON     L4K 5E3
# 6024                  "900 Dufferin Street"      Toronto    ON     M6H 4B1
#
#        latitude   longitude  stars  review_count  is_open  \
# 362   56.077943   -3.397500    4.5             3        1
# 365   33.450762 -111.772613    2.0             7        1
# 373   55.959381   -3.214435    4.5            14        1
# 374   40.497369  -79.845025    3.0             7        1
# 375   40.070779  -88.251750    3.0             5        1
# ...         ...         ...    ...           ...      ...
# 5471  33.493700 -112.236369    2.0            12        1
# 5473  41.495425  -81.987666    2.0             5        1
# 5474  43.096670  -89.498311    3.0             4        1
# 5478  43.836159  -79.506367    1.0             8        1
# 6024  43.656331  -79.435335    2.0            12        0
#
#                                              categories
# 362   Chicken Wings;Desserts;Buffets;Restaurants;Foo...
# 365   Chicken Wings;Fast Food;Restaurants;Pizza;Italian
# 373        Chicken Wings;Italian;Pizza;Food;Restaurants
# 374             Chicken Wings;Italian;Pizza;Restaurants
# 375             Chicken Wings;Italian;Pizza;Restaurants
# ...                                                 ...
# 5471            Restaurants;Pizza;Italian;Chicken Wings
# 5473            Restaurants;Pizza;Italian;Chicken Wings
# 5474            Restaurants;Pizza;Italian;Chicken Wings
# 5478  Restaurants;Pizza;Italian;Fast Food;Chicken Wings
# 6024  Tex-Mex;Fast Food;Italian;Pizza;Restaurants;Ch...
#
# [300 rows x 13 columns]

# %%
pizzahut.describe()
# Out:
#          latitude   longitude       stars  review_count     is_open
# count  300.000000  300.000000  300.000000    300.000000  300.000000
# mean    38.767055  -91.884392    2.261667     12.160000    0.940000
# std      4.687250   21.080315    0.743330     10.658318    0.237884
# min     33.234238 -115.324682    1.000000      3.000000    0.000000
# 25%     35.112221 -112.079480    2.000000      4.000000    1.000000
# 50%     36.304323  -81.764806    2.000000      9.000000    1.000000
# 75%     41.683552  -80.012082    2.500000     15.000000    1.000000
# max     57.481913    9.173350    5.000000     71.000000    1.000000

# %%
littleceasers = yelp.loc[yelp['name'] == '"Little Caesars Pizza"']

# %%
littleceasers.describe()
# Out:
#         latitude   longitude      stars  review_count    is_open
# count  71.000000   71.000000  71.000000     71.000000  71.000000
# mean   36.943075 -101.588974   2.542254     12.690141   0.985915
# std     3.998433   15.423775   0.791682     17.302842   0.118678
# min    33.231942 -115.282305   1.000000      3.000000   0.000000
# 25%    33.481192 -112.349743   2.000000      4.000000   1.000000
# 50%    36.012544 -111.910525   2.500000      8.000000   1.000000
# 75%    41.299636  -81.707586   3.000000     13.000000   1.000000
# max    45.480618  -73.842224   5.000000    116.000000   1.000000

# %%
Pizzanova= yelp.loc[yelp['name'] == '"Pizza Nova"']

# %%
Pizzanova.describe()
# Out:
#         latitude  longitude      stars  review_count  is_open
# count  42.000000  42.000000  42.000000      42.00000     42.0
# mean   43.749309 -79.464962   3.119048       5.50000      1.0
# std     0.104866   0.140029   0.810070       3.63083      0.0
# min    43.559505 -79.787493   1.500000       3.00000      1.0
# 25%    43.666233 -79.522047   2.500000       3.00000      1.0
# 50%    43.753711 -79.428149   3.000000       4.00000      1.0
# 75%    43.805087 -79.369621   3.500000       6.00000      1.0
# max    44.018416 -79.267795   5.000000      20.00000      1.0

# %%
Pizzapizza= yelp.loc[yelp['name'] == '"Pizza Pizza"']

# %%
Pizzapizza.describe()
# Out:
#         latitude  longitude      stars  review_count    is_open
# count  85.000000  85.000000  85.000000     85.000000  85.000000
# mean   43.866197 -78.944980   2.370588      5.635294   0.917647
# std     0.508904   1.610611   0.740628      3.397643   0.276533
# min    43.465832 -79.764834   1.000000      3.000000   0.000000
# 25%    43.657751 -79.487478   2.000000      3.000000   1.000000
# 50%    43.701933 -79.390076   2.500000      4.000000   1.000000
# 75%    43.805447 -79.305024   3.000000      7.000000   1.000000
# max    45.547369 -73.551902   4.000000     20.000000   1.000000

# %%
yelp.loc[yelp['review_count'] > 1000] 
#list all of the restauarnt with over 1000 review count
# Out:
#                  business_id                                   name  \
# 48    JzOp695tclcNCNMuBl7oxA                   "Four Peaks Brewing"
# 971   0FUtlsQrJI7LhqDPxLumEw                     "Joe's Farm Grill"
# 1499  pHJu8tj3sI8eC5aIHLFEfQ               "Nora's Italian Cuisine"
# 1622  N0apJkxIem2E8irTBRKnHw  "Wolfgang Puck Bar & Grill Las Vegas"
# 1631  UYh1N1xQhOh-a7nX92xPzQ                   "Brio Tuscan Grille"
# 1662  LwQB9H3jZ9wTk24Lr-AnZQ               "Spago by Wolfgang Puck"
# 2326  iCQpiavjjPzJ5_3gPD5Ebg                         "Secret Pizza"
# 2633  3GEEy7RP6e4bT4LAiWFMFQ                           "Pizza Rock"
# 3704  3kdSl5mo9dWC4clrQjEDGg                              "Egg & I"
# 5613  pSQFynH1VxkfSmehRXlZWw                      "Pizzeria Bianco"
# 5890  9a3DrZvpYxVs3k_qwlCNSw                                 "Cibo"
# 5958  k1QpHAkzKTrFYfk6u--VgQ                           "The Parlor"
# 5979  RVQE2Z2uky4c0-njFQO66g                   "Midwood Smokehouse"
# 6050  mD7zqv7Y3kvsa_p_MtTayg               "SanTan Brewing Company"
#
#        neighborhood                                            address  \
# 48              NaN                           "1340 E 8th St, Ste 104"
# 971             NaN                            "3000 E Ray Rd, Bldg 1"
# 1499            NaN                               "5780 W Flamingo Rd"
# 1622      The Strip                            "3799 Las Vegas Blvd S"
# 1631      Southeast                              "6653 Las Vegas Blvd"
# 1662      The Strip  "The Forum Shops At Caesars, 3500 Las Vegas Bl...
# 2326      The Strip  "The Cosmopolitan Of Las Vegas, 3708 Las Vegas...
# 2633       Downtown                                     "201 N 3rd St"
# 3704       Westside                         "4533 W Sahara Ave, Ste 5"
# 5613            NaN                                   "623 E Adams St"
# 5890            NaN                                    "603 N 5th Ave"
# 5958            NaN                              "1916 E Camelback Rd"
# 5979  Plaza Midwood                                 "1401 Central Ave"
# 6050            NaN                                "8 S San Marcos Pl"
#
#            city state postal_code   latitude   longitude  stars  review_count  \
# 48        Tempe    AZ       85281  33.419568 -111.916097    4.5          1965
# 971     Gilbert    AZ       85296  33.321824 -111.726057    4.0          1644
# 1499  Las Vegas    NV       89103  36.115052 -115.220284    4.0          1288
# 1622  Las Vegas    NV       89109  36.102543 -115.169884    4.0          1463
# 1631  Las Vegas    NV       89119  36.068152 -115.175930    4.0          1048
# 1662  Las Vegas    NV       89109  36.118831 -115.175638    4.0          1056
# 2326  Las Vegas    NV       89109  36.112372 -115.173064    4.0          3741
# 2633  Las Vegas    NV       89101  36.171618 -115.142267    4.0          1738
# 3704  Las Vegas    NV       89102  36.144046 -115.202465    4.5          2595
# 5613    Phoenix    AZ       85004  33.449160 -112.065635    4.0          2035
# 5890    Phoenix    AZ       85003  33.454960 -112.079908    4.5          1698
# 5958    Phoenix    AZ       85016  33.509446 -112.040395    4.0          1081
# 5979  Charlotte    NC       28205  35.221004  -80.814875    4.5          1192
# 6050   Chandler    AZ       85225  33.303234 -111.842529    4.0          1100
#
#       is_open                                         categories
# 48          1  American (New);Sandwiches;Burgers;Nightlife;Ba...
# 971         1  Italian;American (Traditional);Pizza;Restauran...
# 1499        1  Italian;Wine Bars;Restaurants;Pizza;Bars;Event...
# 1622        1  Nightlife;Salad;Sandwiches;Restaurants;Bars;Am...
# 1631        1  Nightlife;Tuscan;Bars;Italian;Gluten-Free;Rest...
# 1662        1  Pizza;American (Traditional);American (New);Re...
# 2326        1                                  Pizza;Restaurants
# 2633        1                                  Pizza;Restaurants
# 3704        1  Restaurants;Burgers;American (Traditional);San...
# 5613        1         Restaurants;Salad;Pizza;Italian;Sandwiches
# 5890        1               Sandwiches;Pizza;Restaurants;Italian
# 5958        1         Sandwiches;Salad;Italian;Pizza;Restaurants
# 5979        1  Smokehouse;Pizza;Food;Restaurants;Barbeque;Ame...
# 6050        1  Wine Bars;American (New);American (Traditional...

# %%
yelp.loc[yelp['state'] == "NV"]
#list amount of pizza restuants per state "NV" is interchangable to any valid states such as "ON"
# Out:
#                  business_id                               name neighborhood  \
# 1     Ql0iiHl2xpIwtkuC255Wiw  "John's Incredible Pizza Company"     Eastside
# 8     pfmr8R3WH8RXqW0W6D8ffQ           "Lombardi's Romagna Mia"    The Strip
# 13    aQUo8irLBywAZN26ln_Q1w                             "WILD"     Downtown
# 24    bJP4l_BGq2CudEu0m-wNjg         "Artisan Fine Dining Room"          NaN
# 26    LhaOYo_5j5W_JIY5fYPKuQ            "Brooklyn's Restaurant"          NaN
# ...                      ...                                ...          ...
# 6010                  #NAME?           "Double Play Sports Bar"    Southeast
# 6019  LN0JGAl8Rr_r_5t_X8Kz6g             "Fellini's Ristorante"    The Strip
# 6041  sZsJooAzpKqOvDysphkqpQ                     "Pop Up Pizza"     Downtown
# 6047  kG4dBv7FYM7y5msCKb-wcg                     "Bouncy World"          NaN
# 6059  zEaGcSVPDQipnRdEZp-F6g     "Dom DeMarco's Pizzeria & Bar"     Westside
#
#                                  address       city state postal_code  \
# 1                 "3700 S Maryland Pkwy"  Las Vegas    NV       89119
# 8                "3663 Las Vegas Blvd S"  Las Vegas    NV       89109
# 13       "150 N Las Vegas Blvd, Ste 120"  Las Vegas    NV       89101
# 24    "Artisan Hotel, 1501 W Sahara Ave"  Las Vegas    NV       89102
# 26                      "10 Via Brianza"  Henderson    NV       89011
# ...                                  ...        ...   ...         ...
# 6010             "9495 Las Vegas Blvd S"  Las Vegas    NV       89123
# 6019             "2000 Las Vegas Blvd S"  Las Vegas    NV       89104
# 6041                       "1 S Main St"  Las Vegas    NV       89101
# 6047                "225 N Stephanie St"  Henderson    NV       89074
# 6059            "9785 W Charleston Blvd"  Las Vegas    NV       89117
#
#        latitude   longitude  stars  review_count  is_open  \
# 1     36.122106 -115.134871    3.0           268        1
# 8     36.110574 -115.169417    3.5           280        1
# 13    36.170088 -115.139615    4.0           107        0
# 24    36.143672 -115.169792    2.0             3        0
# 26    36.102041 -114.930216    3.0             7        0
# ...         ...         ...    ...           ...      ...
# 6010  36.016693 -115.173115    4.0             7        0
# 6019  36.148133 -115.155773    4.0           163        1
# 6041  36.172176 -115.146829    4.0           278        1
# 6047  36.043545 -115.048153    4.5           188        1
# 6059  36.157822 -115.311202    4.0           575        1
#
#                                              categories
# 1     Active Life;Pizza;Arts & Entertainment;Kids Ac...
# 8     American (New);Breakfast & Brunch;Pizza;Americ...
# 13    American (New);Cocktail Bars;Pizza;Food;Nightl...
# 24             American (New);Pizza;Italian;Restaurants
# 26                     American (New);Pizza;Restaurants
# ...                                                 ...
# 6010       Sports Bars;Pizza;Restaurants;Nightlife;Bars
# 6019              Steakhouses;Pizza;Restaurants;Italian
# 6041                            Vegan;Restaurants;Pizza
# 6047  Venues & Event Spaces;Kids Activities;Recreati...
# 6059  Wine Bars;Nightlife;Restaurants;Pizza;Bars;Ita...
#
# [763 rows x 13 columns]

# %%
NV= yelp.loc[yelp['state'] == "NV"]

# %%
NV.describe()
# Out:
#          latitude   longitude       stars  review_count     is_open
# count  763.000000  763.000000  763.000000    763.000000  763.000000
# mean    36.125157 -115.173321    3.268676    109.507208    0.701180
# std      0.076479    0.086122    0.851447    232.196786    0.458041
# min     35.942475 -115.350952    1.000000      3.000000    0.000000
# 25%     36.069509 -115.243285    2.500000     14.000000    0.000000
# 50%     36.116037 -115.171946    3.500000     39.000000    1.000000
# 75%     36.167327 -115.118289    4.000000    114.500000    1.000000
# max     36.381974 -114.838325    5.000000   3741.000000    1.000000

# %%
AZ= yelp.loc[yelp['state'] == "AZ"]

# %%
AZ.describe()
# Out:
#           latitude    longitude        stars  review_count      is_open
# count  1327.000000  1327.000000  1327.000000   1327.000000  1327.000000
# mean     33.491173  -111.999381     3.365863     86.009043     0.725697
# std       0.129254     0.187601     0.792177    155.695089     0.446331
# min      33.137323  -112.497764     1.000000      3.000000     0.000000
# 25%      33.388714  -112.132860     3.000000     12.000000     0.000000
# 50%      33.480899  -111.978699     3.500000     33.000000     1.000000
# 75%      33.602500  -111.873812     4.000000     96.000000     1.000000
# max      33.873916  -111.506818     5.000000   2035.000000     1.000000

# %%
yelp['state'].value_counts()
# Out:
# AZ     1327
# ON     1075
# OH      765
# NV      763
# PA      739
# QC      450
# NC      420
# WI      177
# BW      149
# IL       88
# EDH      63
# SC       26
# MLN       4
# NYK       4
# 1         3
# CHE       3
# FIF       2
# HLD       2
# C         2
# NY        2
# WHT       1
# CA        1
# WLN       1
# Name: state, dtype: int64

# %%
yelp.isnull()
# Out:
#       business_id   name  neighborhood  address   city  state  postal_code  \
# 0           False  False          True    False  False  False        False
# 1           False  False         False    False  False  False        False
# 2           False  False          True    False  False  False        False
# 3           False  False          True    False  False  False        False
# 4           False  False         False    False  False  False        False
# ...           ...    ...           ...      ...    ...    ...          ...
# 6062        False  False          True    False  False  False        False
# 6063        False  False         False    False  False  False        False
# 6064        False  False          True    False  False  False        False
# 6065        False  False         False    False  False  False        False
# 6066        False  False          True    False  False  False        False
#
#       latitude  longitude  stars  review_count  is_open  categories
# 0        False      False  False         False    False       False
# 1        False      False  False         False    False       False
# 2        False      False  False         False    False       False
# 3        False      False  False         False    False       False
# 4        False      False  False         False    False       False
# ...        ...        ...    ...           ...      ...         ...
# 6062     False      False  False         False    False       False
# 6063     False      False  False         False    False       False
# 6064     False      False  False         False    False       False
# 6065     False      False  False         False    False       False
# 6066     False      False  False         False    False       False
#
# [6067 rows x 13 columns]

# %%
yelp.isnull().sum()
# Out:
# business_id        0
# name               0
# neighborhood    3885
# address            0
# city               0
# state              0
# postal_code        4
# latitude           0
# longitude          0
# stars              0
# review_count       0
# is_open            0
# categories         0
# dtype: int64

# %%
y= yelp[['stars']]
X= yelp[['review_count']]

# %%
X
# Out:
#       review_count
# 0               11
# 1              268
# 2               23
# 3                8
# 4                3
# ...            ...
# 6062            45
# 6063           116
# 6064           337
# 6065            10
# 6066            13
#
# [6067 rows x 1 columns]

# %%
y
# Out:
#       stars
# 0       3.0
# 1       3.0
# 2       4.0
# 3       3.0
# 4       3.5
# ...     ...
# 6062    3.5
# 6063    3.5
# 6064    4.0
# 6065    3.0
# 6066    3.5
#
# [6067 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size =0.2, random_state=10)

# %%
len(X_train)
# Out:
# 4853

# %%
len(X_test)
# Out:
# 1214

# %%
len(y_train)
# Out:
# 4853

# %%
from sklearn.linear_model import LinearRegression
clf = LinearRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
clf.predict(X_test)
# Out:
# array([[3.29254607],
#        [3.62439866],
#        [3.43410556],
#        ...,
#        [3.28906509],
#        [3.29370639],
#        [3.29486671]])

# %%
clf.predict(y_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/base.py:493: FutureWarning: The feature names should match those that were passed during fit. Starting version 1.2, an error will be raised.
# Feature names unseen at fit time:
# - stars
# Feature names seen at fit time, yet now missing:
# - review_count
#
#   warnings.warn(message, FutureWarning)
# array([[3.28790477],
#        [3.29080558],
#        [3.29022542],
#        ...,
#        [3.28906509],
#        [3.28964526],
#        [3.28906509]])

# %%
clf_pred = clf.predict(X_test)

# %%
y_test
# Out:
#       stars
# 3679    2.0
# 4163    4.5
# 5724    4.0
# 4495    4.5
# 3328    4.0
# ...     ...
# 1523    2.5
# 1144    4.5
# 176     3.0
# 2926    3.5
# 3832    3.0
#
# [1214 rows x 1 columns]

# %%
clf.score(X_test, y_test)
# Out:
# 0.03491541103556728

# %%
clf.score(X_train, y_train)
# Out:
# 0.02917716057971298

# %%
yelp[['stars','review_count']].corr()

sns.heatmap(yelp[['stars','review_count']].corr(), annot=True, cmap = 'Reds')
plt.show()

# %%
remove = ['longitude' , 'neighborhood', 'latitude']

yelp.drop(remove, inplace =True, axis =1)

# %%
yelp.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6062    False
# 6063    False
# 6064    False
# 6065    False
# 6066    False
# Length: 6067, dtype: bool

# %%
yelp.drop_duplicates()
# Out:
#                  business_id                               name  \
# 0     sxQrSzv4SS4b6o3tgmWS7A                 "Chuck E Cheese's"
# 1     Ql0iiHl2xpIwtkuC255Wiw  "John's Incredible Pizza Company"
# 2     pbUsYtULpwmhZXlzeTfcww                   "Stone & Barrel"
# 3     gWsWtppVufrGfGWw1HcjOA                      "Dream Lanes"
# 4     T0ju0drMLfXJPNLnEsEYgw                  "Pizza Hot Wings"
# ...                      ...                                ...
# 6062  7JkPRXmtRmspIX_k3zMNvg     "Teatro Pizzeria and Wine Bar"
# 6063  w2IE4nbufBqwrub7CW80xg                 "Goodfellas Pizza"
# 6064  ToFm2DhhTdr0Kv0A7Sdj6g                    "Timo Wine Bar"
# 6065  SHHnB7GsNyA3y5dg-P-LMw                  "Luca's Pizzeria"
# 6066  mSWNf1muSy9wgGtMRgt7Fg        "Zeppe's Tavern & Pizzeria"
#
#                        address             city state postal_code  stars  \
# 0       "1035 Washington Pike"      Bridgeville    PA       15017    3.0
# 1       "3700 S Maryland Pkwy"        Las Vegas    NV       89119    3.0
# 2       "24218 S Oakwood Blvd"        Sun Lakes    AZ       85248    4.0
# 3                "13 Atlas Ct"          Madison    WI       53714    3.0
# 4     "3007 Sheppard Avenue E"          Toronto    ON     M1T 3J5    3.5
# ...                        ...              ...   ...         ...    ...
# 6062   "32409 N Scottsdale Rd"       Scottsdale    AZ       85266    3.5
# 6063      "209 Queen Street S"      Mississauga    ON     L5M 1X3    3.5
# 6064      "8801 N Central Ave"          Phoenix    AZ       85020    4.0
# 6065           "183 Butler St"       Pittsburgh    PA       15223    3.0
# 6066          "25780 Miles Rd"  Bedford Heights    OH       44146    3.5
#
#       review_count  is_open                                         categories
# 0               11        1  Active Life;Arts & Entertainment;Restaurants;V...
# 1              268        1  Active Life;Pizza;Arts & Entertainment;Kids Ac...
# 2               23        1  Active Life;Restaurants;Nightlife;American (Tr...
# 3                8        1  Active Life;Toy Stores;Shopping;Pizza;Event Pl...
# 4                3        0                     Afghan;Halal;Pizza;Restaurants
# ...            ...      ...                                                ...
# 6062            45        0  Wine Bars;Restaurants;Italian;Pizza;Bars;Night...
# 6063           116        1  Wine Bars;Restaurants;Nightlife;Bars;Italian;F...
# 6064           337        1  Wine Bars;Tapas/Small Plates;Pizza;Restaurants...
# 6065            10        0   Wraps;Restaurants;Pizza;Sandwiches;Chicken Wings
# 6066            13        1  Wraps;Sandwiches;American (Traditional);Italia...
#
# [6067 rows x 10 columns]

# %%
yelp['stars'].describe()
# Out:
# count    6067.000000
# mean        3.348772
# std         0.829963
# min         1.000000
# 25%         3.000000
# 50%         3.500000
# 75%         4.000000
# max         5.000000
# Name: stars, dtype: float64

# %%
yelp['review_count'].describe()
# Out:
# count    6067.000000
# mean       49.129553
# std       121.137196
# min         3.000000
# 25%         6.000000
# 50%        15.000000
# 75%        44.000000
# max      3741.000000
# Name: review_count, dtype: float64

# %%
# %matplotlib inline
plt.scatter(yelp['review_count'], yelp['stars'])
